# %%
from ipywidgets import interact
import ipywidgets as widgets

# %%
def f(x):
    return x# Generate a slider 
interact(f, x=10,);
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-…

# %%
# Booleans generate check-boxes
interact(f, x=True);
# Out:
# interactive(children=(Checkbox(value=True, description='x'), Output()), _dom_classes=('widget-interact',))

# %%
# Strings generate text areas
interact(f, x='Hi there!');
# Out:
# interactive(children=(Text(value='Hi there!', description='x'), Output()), _dom_classes=('widget-interact',))

# %%
play = widgets.Play(
    # interval=10,
    value=50,
    min=0,
    max=100,
    step=1,
    description="Press play",
    disabled=False
)
slider = widgets.IntSlider()
widgets.jslink((play, 'value'), (slider, 'value'))
widgets.HBox([play, slider])
# Out:
# HBox(children=(Play(value=50, description='Press play'), IntSlider(value=0)))

# %%
widgets.DatePicker(
    description='Pick a Date',
    disabled=False
)
# Out:
# DatePicker(value=None, description='Pick a Date')

# %%
widgets.ColorPicker(
    concise=False,
    description='Pick a color',
    value='blue',
    disabled=False
)
# Out:
# ColorPicker(value='blue', description='Pick a color')

# %%
tab_contents = ['P0', 'P1', 'P2', 'P3', 'P4']
children = [widgets.Text(description=name) for name in tab_contents]
tab = widgets.Tab()
tab.children = children
for i in range(len(children)):
    tab.set_title(i, str(i))
tab
# Out:
# Tab(children=(Text(value='', description='P0'), Text(value='', description='P1'), Text(value='', description='…

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://data.cityofnewyork.us/resource/h9gi-nx95.csv')
df.head()
# Out:
#                       date   time   borough  zip_code   latitude  longitude  \
# 0  2018-11-19T00:00:00.000  14:20       NaN       NaN  40.685806  -73.80728
# 1  2018-12-09T00:00:00.000   9:48    QUEENS   11362.0  40.756992  -73.72966
# 2  2018-11-29T00:00:00.000  22:00    QUEENS   11369.0  40.767467  -73.88187
# 3  2018-11-02T00:00:00.000  17:16       NaN       NaN        NaN        NaN
# 4  2018-12-11T00:00:00.000  16:50  BROOKLYN   11210.0  40.628647  -73.95207
#
#                  location                    on_street_name  \
# 0  (40.685806, -73.80728)  VAN WYCK EXPWY
# 1  (40.756992, -73.72966)  MARATHON PARKWAY
# 2  (40.767467, -73.88187)  88 STREET
# 3                     NaN  LONG ISLAND EXPRESSWAY
# 4  (40.628647, -73.95207)  BEDFORD AVENUE
#
#      off_street_name cross_street_name  ...   contributing_factor_vehicle_2  \
# 0                NaN               NaN  ...                     Unspecified
# 1          61 AVENUE               NaN  ...                     Unspecified
# 2          23 AVENUE               NaN  ...                             NaN
# 3  KISSENA BOULEVARD               NaN  ...  Driver Inattention/Distraction
# 4           AVENUE I               NaN  ...                     Unspecified
#
#    contributing_factor_vehicle_3  contributing_factor_vehicle_4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    contributing_factor_vehicle_5  unique_key  \
# 0                            NaN     4029022
# 1                            NaN     4041190
# 2                            NaN     4035239
# 3                            NaN     4016550
# 4                            NaN     4042728
#
#                     vehicle_type_code1                   vehicle_type_code2  \
# 0                                Sedan                                 Dump
# 1  Station Wagon/Sport Utility Vehicle                                Sedan
# 2  Station Wagon/Sport Utility Vehicle                                  NaN
# 3  Station Wagon/Sport Utility Vehicle  Station Wagon/Sport Utility Vehicle
# 4  Station Wagon/Sport Utility Vehicle                                Sedan
#
#    vehicle_type_code_3 vehicle_type_code_4 vehicle_type_code_5
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
#
# [5 rows x 29 columns]

# %%
import qgrid
qgrid_widget = qgrid.show_grid(df, show_toolbar = True)
qgrid_widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
qgrid_widget.get_changed_df()
# Out:
#                         date  time    borough  zip_code   latitude  longitude  \
# 140  2018-11-03T00:00:00.000  0:00        NaN       NaN  40.685760 -73.915504
# 684  2018-11-21T00:00:00.000  0:00      BRONX   10457.0  40.844970 -73.902470
# 519  2018-11-10T00:00:00.000  0:00   BROOKLYN   11210.0  40.638397 -73.945330
# 515  2018-11-28T00:00:00.000  0:00   BROOKLYN   11217.0  40.679745 -73.986970
# 785  2018-12-11T00:00:00.000  0:00        NaN       NaN  40.814580 -73.947950
# ..                       ...   ...        ...       ...        ...        ...
# 284  2018-12-03T00:00:00.000  9:47     QUEENS   11101.0  40.744960 -73.935425
# 1    2018-12-09T00:00:00.000  9:48     QUEENS   11362.0  40.756992 -73.729660
# 776  2018-11-13T00:00:00.000  9:50  MANHATTAN   10018.0  40.759514 -73.999260
# 118  2018-11-20T00:00:00.000  9:53  MANHATTAN   10014.0  40.735302 -74.009940
# 76   2018-12-06T00:00:00.000  9:57  MANHATTAN   10035.0  40.804375 -73.937420
#
#                    location                    on_street_name  \
# 140  (40.68576, -73.915504)  BROADWAY
# 684   (40.84497, -73.90247)  WEBSTER AVENUE
# 519  (40.638397, -73.94533)                               NaN
# 515  (40.679745, -73.98697)  NEVINS STREET
# 785   (40.81458, -73.94795)  WEST 132 STREET
# ..                      ...                               ...
# 284  (40.74496, -73.935425)  THOMSON AVENUE
# 1    (40.756992, -73.72966)  MARATHON PARKWAY
# 776  (40.759514, -73.99926)  11 AVENUE
# 118  (40.735302, -74.00994)  WEST STREET
# 76   (40.804375, -73.93742)  EAST 125 STREET
#
#       off_street_name                         cross_street_name  ...  \
# 140     HALSEY STREET                                       NaN  ...
# 684      ITTNER PLACE                                       NaN  ...
# 519               NaN  1403      NEW YORK AVENUE                 ...
# 515    SACKETT STREET                                       NaN  ...
# 785               NaN                                       NaN  ...
# ..                ...                                       ...  ...
# 284         31 STREET                                       NaN  ...
# 1           61 AVENUE                                       NaN  ...
# 776    WEST 40 STREET                                       NaN  ...
# 118    WEST 11 STREET                                       NaN  ...
# 76   LEXINGTON AVENUE                                       NaN  ...
#
#       contributing_factor_vehicle_2  contributing_factor_vehicle_3  \
# 140                     Unspecified                            NaN
# 684                     Unspecified                            NaN
# 519                             NaN                            NaN
# 515                     Unspecified                            NaN
# 785                     Unspecified                            NaN
# ..                              ...                            ...
# 284  Driver Inattention/Distraction                            NaN
# 1                       Unspecified                            NaN
# 776  Passing or Lane Usage Improper                            NaN
# 118                     Unspecified                            NaN
# 76                              NaN                            NaN
#
#      contributing_factor_vehicle_4  contributing_factor_vehicle_5  unique_key  \
# 140                            NaN                            NaN     4014368
# 684                            NaN                            NaN     4030478
# 519                            NaN                            NaN     4020170
# 515                            NaN                            NaN     4034238
# 785                            NaN                            NaN     4042608
# ..                             ...                            ...         ...
# 284                            NaN                            NaN     4037255
# 1                              NaN                            NaN     4041190
# 776                            NaN                            NaN     4029634
# 118                            NaN                            NaN     4029610
# 76                             NaN                            NaN     4039423
#
#                       vehicle_type_code1                   vehicle_type_code2  \
# 140                                Sedan                                Sedan
# 684                                Sedan                                 Taxi
# 519                        Pick-up Truck                                  NaN
# 515  Station Wagon/Sport Utility Vehicle                            Box Truck
# 785                                Sedan  Station Wagon/Sport Utility Vehicle
# ..                                   ...                                  ...
# 284                                 Taxi                                 Taxi
# 1    Station Wagon/Sport Utility Vehicle                                Sedan
# 776                            Box Truck                            Box Truck
# 118                                Sedan  Station Wagon/Sport Utility Vehicle
# 76                                 Sedan                                  NaN
#
#      vehicle_type_code_3 vehicle_type_code_4 vehicle_type_code_5
# 140                  NaN                 NaN                 NaN
# 684                  NaN                 NaN                 NaN
# 519                  NaN                 NaN                 NaN
# 515                  NaN                 NaN                 NaN
# 785                  NaN                 NaN                 NaN
# ..                   ...                 ...                 ...
# 284                  NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 776                  NaN                 NaN                 NaN
# 118                  NaN                 NaN                 NaN
# 76                   NaN                 NaN                 NaN
#
# [1000 rows x 29 columns]
